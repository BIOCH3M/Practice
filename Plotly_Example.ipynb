# %%
    # import numpy as np
    # import pandas as pd
    # url = 'https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/0-02-Pandas-Crash-Course/salaries.csv'
    # df = pd.read_csv(url, error_bad_lines=False)
    # df

# %%
import pandas as pd
import numpy as np
import plotly.offline as pyo
import plotly.graph_objects as go
np.random.seed(42)

# %%
rx=np.random.randint(1,101,100)
ry=np.random.randint(1,101,100)

# %% [markdown]
# ### Scatter

# %%
data=[go.Scatter(x=rx, y=ry, mode='markers', marker={'size':12,
                                                    'color':'rgb(51,205,153)',
                                                    'symbol':'pentagon',
                                                    'line': {'width':2}})]
layout=go.Layout(title='Hello Plot', xaxis={'title':'MY X'},yaxis={'title':'My Y'}, hovermode='closest')

fig=go.Figure(data=data, layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# ### Linechart

# %%
rx=np.linspace(0,1,100)
ry=np.random.randn(100)
trace0=go.Scatter(x=rx, y=ry+5, mode='markers', name='markers' )
trace1=go.Scatter(x=rx, y=ry, mode='lines', name='mylines' )
trace2=go.Scatter(x=rx, y=ry-2, mode='lines+markers', name='mylines+markers' )
data=[trace0, trace1, trace2]
layout=go.Layout(title='Line Chart')
fig=go.Figure(data=data, layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
url='https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/SourceData/nst-est2017-alldata.csv'
df = pd.read_csv(url, error_bad_lines=False)

df.head()
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  CENSUS2010POP  \
# 0    10.0      0        0    0.0     United States    308745538.0
# 1    20.0      1        0    0.0  Northeast Region     55317240.0
# 2    20.0      2        0    0.0    Midwest Region     66927001.0
# 3    20.0      3        0    0.0      South Region    114555744.0
# 4    20.0      4        0    0.0       West Region     71945553.0
#
#    ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  ...  \
# 0        308758105.0      309338421.0      311644280.0      313993272.0  ...
# 1         55318350.0       55388349.0       55642659.0       55860261.0  ...
# 2         66929794.0       66973360.0       67141501.0       67318295.0  ...
# 3        114563024.0      114869241.0      116060993.0      117291728.0  ...
# 4         71946937.0       72107471.0       72799127.0       73522988.0  ...
#
#    RDOMESTICMIG2015  RDOMESTICMIG2016  RDOMESTICMIG2017  RNETMIG2011  \
# ...

# %%
df2=df[df['DIVISION']=='1']

# %%
df2.head()
# Out:
#     SUMLEV REGION DIVISION  STATE           NAME  CENSUS2010POP  \
# 11    40.0      1        1    9.0    Connecticut      3574097.0
# 24    40.0      1        1   23.0          Maine      1328361.0
# 26    40.0      1        1   25.0  Massachusetts      6547629.0
# 34    40.0      1        1   33.0  New Hampshire      1316470.0
# 44    40.0      1        1   44.0   Rhode Island      1052567.0
#
#     ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  ...  \
# 11          3574114.0        3580171.0        3591927.0        3597705.0  ...
# 24          1328362.0        1327568.0        1327968.0        1328101.0  ...
# 26          6547808.0        6564943.0        6612178.0        6659627.0  ...
# 34          1316460.0        1316700.0        1318345.0        1320923.0  ...
# 44          1052945.0        1053169.0        1052154.0        1052761.0  ...
#
#     RDOMESTICMIG2015  RDOMESTICMIG2016  RDOMESTICMIG2017  RNETMIG2011  \
# ...

# %%
df2.set_index('NAME', inplace=True)

# %%
col_list=[col for col in df2.columns if col.startswith('POP')]

# %%
df2.index
# Out:
# Index(['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire',
#        'Rhode Island', 'Vermont'],
#       dtype='object', name='NAME')

# %%
df2=df2[col_list]

# %%
df2.head()
# Out:
#                POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# NAME
# Connecticut          3580171.0        3591927.0        3597705.0
# Maine                1327568.0        1327968.0        1328101.0
# Massachusetts        6564943.0        6612178.0        6659627.0
# New Hampshire        1316700.0        1318345.0        1320923.0
# Rhode Island         1053169.0        1052154.0        1052761.0
#
#                POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# NAME
# Connecticut          3602470.0        3600188.0        3593862.0
# Maine                1327975.0        1328903.0        1327787.0
# Massachusetts        6711138.0        6757925.0        6794002.0
# New Hampshire        1322622.0        1328684.0        1330134.0
# Rhode Island         1052784.0        1054782.0        1055916.0
#
#                POPESTIMATE2016  POPESTIMATE2017
# NAME
# Connecticut          3587685.0        3588184.0
# Maine                1330232.0        1335907.0
# ...

# %%
#Build traces for columns
data=[go.Scatter(x=df2.columns,y=df2.loc[name],mode='lines', name=name) for name in df2.index]
pyo.plot(data)
# Out:
# 'temp-plot.html'

# %% [markdown]
# ### Bar Chart

# %%
url='https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/2018WinterOlympics.csv'
df = pd.read_csv(url, error_bad_lines=False)

df.head()
# Out:
#    Rank            NOC  Gold  Silver  Bronze  Total
# 0     1         Norway    14      14      11     39
# 1     2        Germany    14      10       7     31
# 2     3         Canada    11       8      10     29
# 3     4  United States     9       8       6     23
# 4     5    Netherlands     8       6       6     20

# %%
data=[go.Bar(x=df['NOC'], y=df['Total'])]
layout=go.Layout(title="olympics")
fig=go.Figure(data=data, layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
trace1=go.Bar(x=df['NOC'], y=df['Gold'], name='Gold', marker={'color':'#FFD700'})
trace2=go.Bar(x=df['NOC'], y=df['Silver'], name='Silver', marker={'color':'#9EA0A1'})
trace3=go.Bar(x=df['NOC'], y=df['Bronze'], name='Bronze', marker={'color':'#CD7F32'})

data=[trace1, trace2, trace3]
layout=go.Layout(title="olympics", barmode='stack')
fig=go.Figure(data=data, layout=layout)
pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %%
##
